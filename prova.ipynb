# %%
# import /home/phd2/Scrivania/CorsoRepo/cellPIV/datasets/Farneback/FinalDataset.csv and count based on "BLASTO NY" column. How many 1 and 0 are there?
import pandas as pd
df = pd.read_csv('/home/phd2/Scrivania/CorsoRepo/cellPIV/datasets/Farneback/FinalDataset.csv')
count_1 = df['BLASTO NY'].value_counts().get(1, 0)
count_0 = df['BLASTO NY'].value_counts().get(0, 0)
print(f'Count of 1: {count_1}')
print(f'Count of 0: {count_0}')
# Out:
# Count of 1: 2537
# Count of 0: 2474

# %%
# count original
# import pandas as pd
df = pd.read_csv('/home/phd2/Scrivania/CorsoRepo/cellPIV/datasets/DB_Morpheus_withID.csv')
count_1 = df['BLASTO NY'].value_counts().get(1, 0)
count_0 = df['BLASTO NY'].value_counts().get(0, 0)
print(f'Count of 1: {count_1}')
print(f'Count of 0: {count_0}')
# Out:
# Count of 1: 2556
# Count of 0: 3496
