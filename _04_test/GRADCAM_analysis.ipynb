# %% [markdown]
# # Config and import

# %%
OUTPUT_DIR = "/home/phd2/Documenti/embryo_to_send_gradcam/small_batch"

# %% [markdown]
# # Helpers

# %% [markdown]
# # Csv Analysis

# %% [markdown]
# # Show some example

# %% [markdown]
# # Select videos, compute optical flow, compute gradmac, copy them (plain_videos, overlay_arrays, gradcam_maps)
