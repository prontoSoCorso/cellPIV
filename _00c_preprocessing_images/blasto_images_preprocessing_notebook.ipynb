# %% [markdown]
# # Preprocessing Immagini Blastocisti
#
# **Caratteristiche principali:**
# - Rilevamento della root `cellPIV` e import opzionale di `config` (fallback se non presente).
# - Funzione per organizzare i video per classificazione (`blasto` / `no_blasto`).
# - Verifica immagini corrotte con log e riepilogo.
# - Funzione per tentare di correggere JPEG troncati.
# - Opzioni `DRY_RUN` e `FIX_IMAGES` per non eseguire modifiche senza volerlo.
#
# **Istruzioni d'uso:** esegui le celle nell'ordine. Imposta le opzioni (SRC_DIR, DEST_DIR, EXCEL_PATH, DRY_RUN, FIX_IMAGES) nella cella dei parametri prima di lanciare le operazioni.

# %%
# %matplotlib inline
import os, sys, shutil, logging, time
from pathlib import Path
import pandas as pd
from PIL import Image, ImageFile

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

cwd = Path().resolve()
root = cwd
for _ in range(10):
    if root.name == 'cellPIV':
        break
    if root.parent == root:
        break
    root = root.parent

fallback_root = Path('/home/phd2/Scrivania/CorsoRepo/cellPIV')
if root.name != 'cellPIV':
    root = fallback_root

if str(root) not in sys.path:
    sys.path.append(str(root))

try:
    from config import Config_00_preprocessing as conf
    print("Imported conf from config.Config_00_preprocessing")
except Exception as e:
    conf = None
    print("Could not import conf (ok). Please set paths manually if needed.")

print("Using root:", root)
# Out:
# Imported conf from config.Config_00_preprocessing
# Using root: /home/phd2/Scrivania/CorsoRepo/cellPIV

# %%
from pathlib import Path
try:
    SRC_DIR = Path(conf.dest_dir_time_conversion) if conf and hasattr(conf, 'dest_dir_time_conversion') else (_ for _ in ()).throw(ValueError("conf.dest_dir_time_conversion not set"))
    DEST_DIR = Path(conf.dest_dir_blastoData) if conf and hasattr(conf, 'dest_dir_blastoData') else (_ for _ in ()).throw(ValueError("conf.dest_dir_blastoData not set"))
    EXCEL_PATH = Path(conf.filtered_blasto_dataset) if conf and hasattr(conf, 'filtered_blasto_dataset') else (_ for _ in ()).throw(ValueError("conf.filtered_blasto_dataset not set"))
except Exception as e:
    raise RuntimeError(f"Error setting SRC_DIR or DEST_DIR: {e}")

DRY_RUN = False
FIX_IMAGES = True
SAVE_LOGS = True
MAX_FIX_FILES = None
IMAGE_EXTENSIONS = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.gif')

print("SRC_DIR =", SRC_DIR)
print("DEST_DIR =", DEST_DIR)
print("EXCEL_PATH =", EXCEL_PATH)
print("DRY_RUN =", DRY_RUN, "FIX_IMAGES =", FIX_IMAGES, "SAVE_LOGS =", SAVE_LOGS)
# Out:
# SRC_DIR = /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion
# DEST_DIR = /home/phd2/Scrivania/CorsoData/blastocisti
# EXCEL_PATH = /home/phd2/Scrivania/CorsoRepo/cellPIV/datasets/filtered_blasto_dataset.csv
# DRY_RUN = False FIX_IMAGES = True SAVE_LOGS = True

# %%
from pathlib import Path
import shutil
import logging
import pandas as pd

def organize_videos_by_classification(src_dir, dest_dir, excel_path, dry_run=True, save_logs=True):
    """
    Robust copy/move that handles directories and files:
    - If video_path is dir -> use shutil.copytree
    - If file -> use shutil.copy2
    - If dest exists -> create dest_name_dupN to avoid overwriting
    - dry_run=True only simula le operazioni e logga le azioni
    """
    stats = {'moved_count': 0, 'not_moved': [], 'errors': []}
    blasto_dir = Path(dest_dir) / "blasto"
    no_blasto_dir = Path(dest_dir) / "no_blasto"
    if not dry_run:
        blasto_dir.mkdir(parents=True, exist_ok=True)
        no_blasto_dir.mkdir(parents=True, exist_ok=True)

    try:
        if not Path(excel_path).exists():
            raise FileNotFoundError(f"Excel file {excel_path} does not exist")
        else:
            if not str(excel_path).lower().endswith(('.xls', '.xlsx')):
                df = pd.read_csv(excel_path)
            else:
                df = pd.read_excel(excel_path)
    except Exception as e:
        raise RuntimeError(f"Could not read excel {excel_path}: {e}")

    # Normalizza i nomi delle colonne in minuscolo
    df.columns = df.columns.str.lower()
    required_columns = ['dish_well', 'blasto ny']
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"Excel must contain all of the following columns: {required_columns}")

    relevant = df[required_columns].copy()

    for _, row in relevant.iterrows():
        video_name = str(row['dish_well']).strip()

        # classification check
        try:
            classification = int(row['blasto ny'])
        except Exception:
            stats['not_moved'].append(f"{video_name}: invalid classification")
            continue

        # build source path (try year-extraction, fallback simple join)
        try:
            year = video_name.split("_")[0][1:5]
            video_path = Path(src_dir) / year / video_name
        except Exception:
            video_path = Path(src_dir) / video_name

        if not video_path.exists():
            stats['not_moved'].append(f"{video_name} not found at {video_path}")
            continue

        target_dir = blasto_dir if classification == 1 else no_blasto_dir
        dest_path = Path(target_dir) / video_path.name

        # ensure target parent exists for files
        try:
            if video_path.is_dir():
                # If dest exists -> find unique name
                if dest_path.exists():
                    i = 1
                    new_dest = dest_path.with_name(dest_path.name + f"_dup{i}")
                    while new_dest.exists():
                        i += 1
                        new_dest = dest_path.with_name(dest_path.name + f"_dup{i}")
                    dest_path = new_dest

                if dry_run:
                    logging.info(f"[DRY_RUN] Would copytree: {video_path} -> {dest_path}")
                else:
                    shutil.copytree(str(video_path), str(dest_path))
                    logging.info(f"Copied directory: {video_path} -> {dest_path}")

            elif video_path.is_file():
                dest_path.parent.mkdir(parents=True, exist_ok=True)
                # If dest exists -> find unique filename
                if dest_path.exists():
                    base = dest_path.stem
                    suf = dest_path.suffix
                    i = 1
                    new_dest = dest_path.with_name(f"{base}_dup{i}{suf}")
                    while new_dest.exists():
                        i += 1
                        new_dest = dest_path.with_name(f"{base}_dup{i}{suf}")
                    dest_path = new_dest

                if dry_run:
                    logging.info(f"[DRY_RUN] Would copy2: {video_path} -> {dest_path}")
                else:
                    shutil.copy2(str(video_path), str(dest_path))
                    logging.info(f"Copied file: {video_path} -> {dest_path}")

            else:
                stats['not_moved'].append(f"{video_name}: exists but not file/dir ({video_path})")

            stats['moved_count'] += 1

        except IsADirectoryError as e:
            msg = f"IsADirectoryError processing {video_path}: {e}"
            logging.warning(msg)
            stats['errors'].append(msg)
        except PermissionError as e:
            msg = f"PermissionError processing {video_path}: {e}"
            logging.warning(msg)
            stats['errors'].append(msg)
        except Exception as e:
            msg = f"Error processing {video_name}: {e}"
            logging.warning(msg)
            stats['errors'].append(msg)

    # Save log if requested
    if save_logs:
        dest_dirp = Path(dest_dir)
        dest_dirp.mkdir(parents=True, exist_ok=True)
        log_path = dest_dirp / "videos_not_moved.txt"
        with open(log_path, 'w') as f:
            f.write("Video non spostati e motivazioni:\n\n")
            f.write("\n".join(stats['not_moved']))
            f.write(f"\n\nTotale video processati (tentativi): {len(relevant)}\n")
            f.write(f"Totale video copiati (counted moves): {stats['moved_count']}\n")
            if stats['errors']:
                f.write("\nErrors:\n")
                f.write("\n".join(stats['errors']))
    return stats


def check_for_corrupted_images(root_dir, log_file_path=None, image_extensions=IMAGE_EXTENSIONS):
    root_dir = Path(root_dir)
    corrupted_folders = []
    total_images = 0
    corrupted_images = 0
    per_folder = {}
    for folder_name in sorted(os.listdir(root_dir)):
        folder_path = root_dir / folder_name
        if not folder_path.is_dir():
            continue
        folder_corrupted = False
        folder_total = 0
        folder_corrupted_count = 0
        for dirpath, _, files in os.walk(folder_path):
            for file_name in files:
                if file_name.lower().endswith(image_extensions):
                    folder_total += 1
                    total_images += 1
                    image_path = Path(dirpath) / file_name
                    try:
                        with Image.open(image_path) as img:
                            img.verify()
                    except Exception as e:
                        folder_corrupted_count += 1
                        corrupted_images += 1
                        folder_corrupted = True
        per_folder[folder_name] = {'total': folder_total, 'corrupted': folder_corrupted_count}
        if folder_corrupted:
            corrupted_folders.append(folder_name)
    summary = {
        'total_images': total_images,
        'corrupted_images': corrupted_images,
        'corrupted_folders_count': len(corrupted_folders),
        'corrupted_folders': corrupted_folders,
        'per_folder': per_folder
    }
    if log_file_path:
        with open(log_file_path, 'w') as lf:
            lf.write("Verifica immagini corrotte:\n\n")
            for folder, vals in per_folder.items():
                lf.write(f"Folder: {folder} -> total: {vals['total']} corrupted: {vals['corrupted']}\n")
            lf.write("\n--- Riassunto ---\n")
            lf.write(f"Totale immagini controllate: {total_images}\n")
            lf.write(f"Totale immagini corrotte: {corrupted_images}\n")
            lf.write(f"Cartelle con immagini corrotte: {len(corrupted_folders)}\n")
            lf.write(f"Cartelle corrotte: {', '.join(corrupted_folders) if corrupted_folders else 'Nessuna'}\n")
    return summary

def fix_truncated_jpeg(file_path):
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    try:
        with Image.open(file_path) as img:
            img.save(file_path, "JPEG")
        return True
    except Exception as e:
        logging.warning(f"Could not fix {file_path}: {e}")
        return False

def fix_images_in_directory(root_path, image_extensions=('.jpg',), max_files=None):
    fixed = 0
    attempted = 0
    errors = []
    for dirpath, _, files in os.walk(root_path):
        for file in files:
            if max_files is not None and attempted >= max_files:
                return {'attempted': attempted, 'fixed': fixed, 'errors': errors}
            if file.lower().endswith(image_extensions):
                attempted += 1
                fp = Path(dirpath) / file
                success = fix_truncated_jpeg(fp)
                if success:
                    fixed += 1
    return {'attempted': attempted, 'fixed': fixed, 'errors': errors}

# %%
print("--- Organizzazione video per classificazione ---")
print("DRY_RUN =", DRY_RUN)
stats = organize_videos_by_classification(SRC_DIR, DEST_DIR, EXCEL_PATH, dry_run=DRY_RUN, save_logs=SAVE_LOGS)
print("Risultati organizzazione:")
print(f"  Moved count (attempts counted): {stats.get('moved_count')}")
print(f"  Not moved examples (first 20):\n{stats.get('not_moved')[:20]}")
if stats.get('errors'):
    print("  Errors:")
    for e in stats.get('errors')[:10]:
        print("   ", e)
# Out:
# --- Organizzazione video per classificazione ---
# DRY_RUN = False
# 2025-09-02 13:42:35,744 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.02.19_S0675_I141_1
# 2025-09-02 13:42:35,823 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.02.19_S0675_I141_2
# 2025-09-02 13:42:35,912 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.02.19_S0675_I141_3
# 2025-09-02 13:42:36,023 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.02.19_S0675_I141_4
# 2025-09-02 13:42:36,114 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.02.19_S0675_I141_5
# 2025-09-02 13:42:36,218 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.02.19_S0675_I141_6
# 2025-09-02 13:42:36,304 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.02.19_S0675_I141_7
# 2025-09-02 13:42:36,388 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.02.19_S0675_I141_8
# 2025-09-02 13:42:36,469 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.02.19_S0675_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.02.19_S0675_I141_9
# 2025-09-02 13:42:36,554 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_1
# 2025-09-02 13:42:36,646 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.03.09_S0695_I141_2
# 2025-09-02 13:42:36,723 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_3
# 2025-09-02 13:42:36,816 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_4
# 2025-09-02 13:42:36,892 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_5
# 2025-09-02 13:42:36,990 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.03.09_S0695_I141_6
# 2025-09-02 13:42:37,081 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_7
# 2025-09-02 13:42:37,157 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.03.09_S0695_I141_8
# 2025-09-02 13:42:37,229 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.03.09_S0695_I141_9
# 2025-09-02 13:42:37,304 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.03.09_S0695_I141_10
# 2025-09-02 13:42:37,374 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.03.09_S0695_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.03.09_S0695_I141_11
# 2025-09-02 13:42:37,465 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.04.26_S0732_I141_1
# 2025-09-02 13:42:37,529 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.04.26_S0732_I141_2
# 2025-09-02 13:42:37,618 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.04.26_S0732_I141_3
# 2025-09-02 13:42:37,705 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.04.26_S0732_I141_4
# 2025-09-02 13:42:37,803 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.04.26_S0732_I141_5
# 2025-09-02 13:42:37,877 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.04.26_S0732_I141_6
# 2025-09-02 13:42:37,946 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.04.26_S0732_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.04.26_S0732_I141_7
# 2025-09-02 13:42:38,044 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.03_S0739_I141_1
# 2025-09-02 13:42:38,142 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.03_S0739_I141_2
# 2025-09-02 13:42:38,224 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.03_S0739_I141_3
# 2025-09-02 13:42:38,316 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.03_S0739_I141_4
# 2025-09-02 13:42:38,401 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.03_S0739_I141_5
# 2025-09-02 13:42:38,514 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.03_S0739_I141_6
# 2025-09-02 13:42:38,598 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.03_S0739_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.03_S0739_I141_7
# 2025-09-02 13:42:38,683 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.04_S0741_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.04_S0741_I141_1
# 2025-09-02 13:42:38,772 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.04_S0741_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.04_S0741_I141_2
# 2025-09-02 13:42:38,845 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.04_S0741_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.04_S0741_I141_3
# 2025-09-02 13:42:38,932 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.04_S0741_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.04_S0741_I141_4
# 2025-09-02 13:42:39,023 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_1
# 2025-09-02 13:42:39,155 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.13_S0749_I141_2
# 2025-09-02 13:42:39,280 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_3
# 2025-09-02 13:42:39,391 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.13_S0749_I141_4
# 2025-09-02 13:42:39,509 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_5
# 2025-09-02 13:42:39,609 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_6
# 2025-09-02 13:42:39,699 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_7
# 2025-09-02 13:42:39,797 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_8
# 2025-09-02 13:42:39,893 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.05.13_S0749_I141_9
# 2025-09-02 13:42:39,999 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_10
# 2025-09-02 13:42:40,087 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_11
# 2025-09-02 13:42:40,199 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.05.13_S0749_I141_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.05.13_S0749_I141_12
# 2025-09-02 13:42:40,278 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_1
# 2025-09-02 13:42:40,368 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_2
# 2025-09-02 13:42:40,463 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_3
# 2025-09-02 13:42:40,584 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_4
# 2025-09-02 13:42:40,664 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_5
# 2025-09-02 13:42:40,744 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_6
# 2025-09-02 13:42:40,829 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0792_I141_7
# 2025-09-02 13:42:40,918 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0792_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.06.22_S0792_I141_8
# 2025-09-02 13:42:41,006 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0795_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.06.22_S0795_I141_1
# 2025-09-02 13:42:41,086 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0795_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.06.22_S0795_I141_2
# 2025-09-02 13:42:41,157 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0795_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.06.22_S0795_I141_3
# 2025-09-02 13:42:41,234 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0795_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.06.22_S0795_I141_4
# 2025-09-02 13:42:41,309 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.06.22_S0795_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.06.22_S0795_I141_5
# 2025-09-02 13:42:41,438 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.15_S0811_I141_1
# 2025-09-02 13:42:41,548 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.15_S0811_I141_2
# 2025-09-02 13:42:41,652 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_3
# 2025-09-02 13:42:41,743 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_4
# 2025-09-02 13:42:41,839 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.15_S0811_I141_5
# 2025-09-02 13:42:41,951 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_6
# 2025-09-02 13:42:42,072 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_7
# 2025-09-02 13:42:42,162 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_8
# 2025-09-02 13:42:42,274 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_9
# 2025-09-02 13:42:42,375 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_10
# 2025-09-02 13:42:42,468 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.15_S0811_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.15_S0811_I141_11
# 2025-09-02 13:42:42,551 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_1
# 2025-09-02 13:42:42,626 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.16_S0812_I141_2
# 2025-09-02 13:42:42,723 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_3
# 2025-09-02 13:42:42,809 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_4
# 2025-09-02 13:42:42,919 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_5
# 2025-09-02 13:42:43,047 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_6
# 2025-09-02 13:42:43,136 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.16_S0812_I141_7
# 2025-09-02 13:42:43,214 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.07.16_S0812_I141_8
# 2025-09-02 13:42:43,294 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.07.16_S0812_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.07.16_S0812_I141_9
# 2025-09-02 13:42:43,366 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.21_S0829_I141_1
# 2025-09-02 13:42:43,442 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_2
# 2025-09-02 13:42:43,523 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_3
# 2025-09-02 13:42:43,618 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_4
# 2025-09-02 13:42:43,700 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_5
# 2025-09-02 13:42:43,784 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_6
# 2025-09-02 13:42:43,866 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_7
# 2025-09-02 13:42:43,961 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.21_S0829_I141_8
# 2025-09-02 13:42:44,052 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_9
# 2025-09-02 13:42:44,124 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_10
# 2025-09-02 13:42:44,205 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_11
# 2025-09-02 13:42:44,289 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.21_S0829_I141_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.21_S0829_I141_12
# 2025-09-02 13:42:44,354 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_1
# 2025-09-02 13:42:44,422 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0830_I141_2
# 2025-09-02 13:42:44,495 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0830_I141_3
# 2025-09-02 13:42:44,570 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0830_I141_4
# 2025-09-02 13:42:44,638 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_5
# 2025-09-02 13:42:44,705 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_6
# 2025-09-02 13:42:44,803 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_7
# 2025-09-02 13:42:44,872 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_8
# 2025-09-02 13:42:44,938 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0830_I141_9
# 2025-09-02 13:42:45,003 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0830_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0830_I141_10
# 2025-09-02 13:42:45,093 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0831_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0831_I141_1
# 2025-09-02 13:42:45,165 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0831_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.23_S0831_I141_2
# 2025-09-02 13:42:45,231 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0831_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0831_I141_3
# 2025-09-02 13:42:45,299 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0831_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0831_I141_4
# 2025-09-02 13:42:45,369 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.23_S0831_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.23_S0831_I141_5
# 2025-09-02 13:42:45,443 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.27_S0834_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.27_S0834_I141_1
# 2025-09-02 13:42:45,523 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.27_S0834_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.09.27_S0834_I141_2
# 2025-09-02 13:42:45,615 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.27_S0834_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.27_S0834_I141_3
# 2025-09-02 13:42:45,719 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.09.27_S0834_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.09.27_S0834_I141_4
# 2025-09-02 13:42:45,823 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.01_S0838_I141_1
# 2025-09-02 13:42:45,926 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.01_S0838_I141_2
# 2025-09-02 13:42:46,003 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.01_S0838_I141_3
# 2025-09-02 13:42:46,082 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.01_S0838_I141_4
# 2025-09-02 13:42:46,167 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.01_S0838_I141_5
# 2025-09-02 13:42:46,272 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.01_S0838_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.01_S0838_I141_6
# 2025-09-02 13:42:46,367 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_1
# 2025-09-02 13:42:46,450 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.03_S0841_I141_2
# 2025-09-02 13:42:46,548 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_3
# 2025-09-02 13:42:46,640 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_4
# 2025-09-02 13:42:46,733 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.03_S0841_I141_5
# 2025-09-02 13:42:46,844 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_6
# 2025-09-02 13:42:46,920 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.03_S0841_I141_7
# 2025-09-02 13:42:47,003 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_8
# 2025-09-02 13:42:47,089 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_9
# 2025-09-02 13:42:47,161 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.03_S0841_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.03_S0841_I141_10
# 2025-09-02 13:42:47,243 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_1
# 2025-09-02 13:42:47,263 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_2
# 2025-09-02 13:42:47,282 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_3
# 2025-09-02 13:42:47,300 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.07_S0844_I141_4
# 2025-09-02 13:42:47,318 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_5
# 2025-09-02 13:42:47,337 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_6
# 2025-09-02 13:42:47,355 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_7
# 2025-09-02 13:42:47,373 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_8
# 2025-09-02 13:42:47,391 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.07_S0844_I141_9
# 2025-09-02 13:42:47,468 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_10
# 2025-09-02 13:42:47,544 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_11
# 2025-09-02 13:42:47,600 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.07_S0844_I141_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.07_S0844_I141_12
# 2025-09-02 13:42:47,616 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.08_S0845_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.08_S0845_I141_1
# 2025-09-02 13:42:47,633 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.08_S0845_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.08_S0845_I141_2
# 2025-09-02 13:42:47,651 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.08_S0845_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.08_S0845_I141_3
# 2025-09-02 13:42:47,689 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.08_S0845_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.08_S0845_I141_4
# 2025-09-02 13:42:47,751 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_1
# 2025-09-02 13:42:47,823 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_2
# 2025-09-02 13:42:47,886 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_3
# 2025-09-02 13:42:47,948 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_4
# 2025-09-02 13:42:48,013 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.09_S0847_I141_5
# 2025-09-02 13:42:48,101 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_6
# 2025-09-02 13:42:48,182 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.09_S0847_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.09_S0847_I141_7
# 2025-09-02 13:42:48,274 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.15_S0850_I141_1
# 2025-09-02 13:42:48,359 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_2
# 2025-09-02 13:42:48,441 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_3
# 2025-09-02 13:42:48,532 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.15_S0850_I141_4
# 2025-09-02 13:42:48,616 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_5
# 2025-09-02 13:42:48,698 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_6
# 2025-09-02 13:42:48,785 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_7
# 2025-09-02 13:42:48,875 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.15_S0850_I141_8
# 2025-09-02 13:42:48,966 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.15_S0850_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.15_S0850_I141_9
# 2025-09-02 13:42:49,056 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0855_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.18_S0855_I141_1
# 2025-09-02 13:42:49,131 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0855_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.18_S0855_I141_2
# 2025-09-02 13:42:49,197 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0855_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.18_S0855_I141_3
# 2025-09-02 13:42:49,265 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0855_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.18_S0855_I141_4
# 2025-09-02 13:42:49,333 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0856_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.18_S0856_I141_1
# 2025-09-02 13:42:49,396 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0856_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.18_S0856_I141_2
# 2025-09-02 13:42:49,474 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0856_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.18_S0856_I141_3
# 2025-09-02 13:42:49,537 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0856_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.18_S0856_I141_4
# 2025-09-02 13:42:49,607 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.18_S0856_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.18_S0856_I141_5
# 2025-09-02 13:42:49,688 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_1
# 2025-09-02 13:42:49,769 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_2
# 2025-09-02 13:42:49,849 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_3
# 2025-09-02 13:42:49,928 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_4
# 2025-09-02 13:42:50,002 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_5
# 2025-09-02 13:42:50,084 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_6
# 2025-09-02 13:42:50,171 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.22_S0857_I141_7
# 2025-09-02 13:42:50,278 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.22_S0857_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.22_S0857_I141_8
# 2025-09-02 13:42:50,369 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_1
# 2025-09-02 13:42:50,432 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_2
# 2025-09-02 13:42:50,507 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.23_S0858_I141_3
# 2025-09-02 13:42:50,585 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.23_S0858_I141_4
# 2025-09-02 13:42:50,674 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.23_S0858_I141_5
# 2025-09-02 13:42:50,778 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_6
# 2025-09-02 13:42:50,877 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.23_S0858_I141_7
# 2025-09-02 13:42:50,957 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.23_S0858_I141_8
# 2025-09-02 13:42:51,039 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_9
# 2025-09-02 13:42:51,118 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_10
# 2025-09-02 13:42:51,191 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_11
# 2025-09-02 13:42:51,260 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.23_S0858_I141_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.23_S0858_I141_12
# 2025-09-02 13:42:51,322 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.29_S0863_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.29_S0863_I141_1
# 2025-09-02 13:42:51,399 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.29_S0863_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.29_S0863_I141_2
# 2025-09-02 13:42:51,479 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.29_S0863_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.29_S0863_I141_3
# 2025-09-02 13:42:51,574 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0864_I141_1
# 2025-09-02 13:42:51,667 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0864_I141_2
# 2025-09-02 13:42:51,746 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0864_I141_3
# 2025-09-02 13:42:51,821 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0864_I141_4
# 2025-09-02 13:42:51,919 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0864_I141_5
# 2025-09-02 13:42:52,002 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0864_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0864_I141_6
# 2025-09-02 13:42:52,081 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_1
# 2025-09-02 13:42:52,162 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0865_I141_2
# 2025-09-02 13:42:52,244 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_3
# 2025-09-02 13:42:52,329 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_4
# 2025-09-02 13:42:52,402 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0865_I141_5
# 2025-09-02 13:42:52,485 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_6
# 2025-09-02 13:42:52,556 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0865_I141_7
# 2025-09-02 13:42:52,633 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_8
# 2025-09-02 13:42:52,710 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0865_I141_9
# 2025-09-02 13:42:52,793 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_10
# 2025-09-02 13:42:52,860 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_11
# 2025-09-02 13:42:52,947 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0865_I141_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0865_I141_12
# 2025-09-02 13:42:53,026 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0866_I141_1
# 2025-09-02 13:42:53,101 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0866_I141_2
# 2025-09-02 13:42:53,182 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0866_I141_3
# 2025-09-02 13:42:53,262 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0866_I141_4
# 2025-09-02 13:42:53,341 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0866_I141_5
# 2025-09-02 13:42:53,423 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2013.10.30_S0866_I141_6
# 2025-09-02 13:42:53,502 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2013/D2013.10.30_S0866_I141_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2013.10.30_S0866_I141_7
# ...
# 2025-09-02 13:53:15,167 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.11.26_S02689_I0141_D_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.11.26_S02689_I0141_D_11
# 2025-09-02 13:53:15,269 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.11.26_S02689_I0141_D_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.11.26_S02689_I0141_D_12
# 2025-09-02 13:53:15,375 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.11.28_S02690_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.11.28_S02690_I0141_D_1
# 2025-09-02 13:53:15,459 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.11.28_S02690_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.11.28_S02690_I0141_D_2
# 2025-09-02 13:53:15,563 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.02_S02692_I0141_D_1
# 2025-09-02 13:53:15,656 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02692_I0141_D_2
# 2025-09-02 13:53:15,800 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02692_I0141_D_3
# 2025-09-02 13:53:15,921 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02692_I0141_D_4
# 2025-09-02 13:53:16,126 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02692_I0141_D_5
# 2025-09-02 13:53:16,235 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02692_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.02_S02692_I0141_D_6
# 2025-09-02 13:53:16,343 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_1
# 2025-09-02 13:53:16,430 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_2
# 2025-09-02 13:53:16,526 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_3
# 2025-09-02 13:53:16,646 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_4
# 2025-09-02 13:53:16,747 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_5
# 2025-09-02 13:53:16,856 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_6
# 2025-09-02 13:53:17,053 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_7
# 2025-09-02 13:53:17,147 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.02_S02694_I0141_D_8
# 2025-09-02 13:53:17,240 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_9 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_9
# 2025-09-02 13:53:17,324 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_10 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_10
# 2025-09-02 13:53:17,406 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_11 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_11
# 2025-09-02 13:53:17,617 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.02_S02694_I0141_D_12 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.02_S02694_I0141_D_12
# 2025-09-02 13:53:17,737 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.04_S02698_I0141_D_1
# 2025-09-02 13:53:17,832 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.04_S02698_I0141_D_2
# 2025-09-02 13:53:17,914 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.04_S02698_I0141_D_3
# 2025-09-02 13:53:17,996 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.04_S02698_I0141_D_4
# 2025-09-02 13:53:18,079 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.04_S02698_I0141_D_5
# 2025-09-02 13:53:18,212 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.04_S02698_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.04_S02698_I0141_D_6
# 2025-09-02 13:53:18,320 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.09_S02701_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.09_S02701_I0141_D_1
# 2025-09-02 13:53:18,422 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.09_S02701_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.09_S02701_I0141_D_2
# 2025-09-02 13:53:18,537 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.09_S02701_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.09_S02701_I0141_D_3
# 2025-09-02 13:53:18,662 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.09_S02701_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.09_S02701_I0141_D_4
# 2025-09-02 13:53:18,806 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.10_S02703_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.10_S02703_I0141_D_1
# 2025-09-02 13:53:19,482 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.10_S02703_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.10_S02703_I0141_D_2
# 2025-09-02 13:53:21,477 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.10_S02703_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.10_S02703_I0141_D_3
# 2025-09-02 13:53:21,607 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.10_S02703_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.10_S02703_I0141_D_4
# 2025-09-02 13:53:21,705 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.17_S02708_I0141_D_1
# 2025-09-02 13:53:21,799 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.17_S02708_I0141_D_2
# 2025-09-02 13:53:21,891 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.17_S02708_I0141_D_3
# 2025-09-02 13:53:21,993 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.17_S02708_I0141_D_4
# 2025-09-02 13:53:22,088 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.17_S02708_I0141_D_5
# 2025-09-02 13:53:22,197 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.17_S02708_I0141_D_6
# 2025-09-02 13:53:22,294 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.17_S02708_I0141_D_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.17_S02708_I0141_D_7
# 2025-09-02 13:53:22,380 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02709_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.18_S02709_I0141_D_1
# 2025-09-02 13:53:22,462 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02709_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.18_S02709_I0141_D_2
# 2025-09-02 13:53:22,538 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02709_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.18_S02709_I0141_D_3
# 2025-09-02 13:53:22,646 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02709_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.18_S02709_I0141_D_4
# 2025-09-02 13:53:22,745 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02710_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.18_S02710_I0141_D_1
# 2025-09-02 13:53:22,829 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.18_S02710_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.18_S02710_I0141_D_2
# 2025-09-02 13:53:22,938 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.23_S02713_I0141_D_1
# 2025-09-02 13:53:23,042 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.23_S02713_I0141_D_2
# 2025-09-02 13:53:23,154 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.23_S02713_I0141_D_3
# 2025-09-02 13:53:23,254 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.23_S02713_I0141_D_4
# 2025-09-02 13:53:23,373 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.23_S02713_I0141_D_5
# 2025-09-02 13:53:23,463 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.23_S02713_I0141_D_6
# 2025-09-02 13:53:23,551 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_7 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.23_S02713_I0141_D_7
# 2025-09-02 13:53:23,643 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.23_S02713_I0141_D_8 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.23_S02713_I0141_D_8
# 2025-09-02 13:53:23,725 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.24_S02714_I0141_D_1
# 2025-09-02 13:53:23,799 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.24_S02714_I0141_D_2
# 2025-09-02 13:53:23,880 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.24_S02714_I0141_D_3
# 2025-09-02 13:53:23,963 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.24_S02714_I0141_D_4
# 2025-09-02 13:53:24,057 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_5 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.24_S02714_I0141_D_5
# 2025-09-02 13:53:24,149 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.24_S02714_I0141_D_6 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.24_S02714_I0141_D_6
# 2025-09-02 13:53:24,257 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.27_S02715_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.27_S02715_I0141_D_1
# 2025-09-02 13:53:24,341 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.27_S02715_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.27_S02715_I0141_D_2
# 2025-09-02 13:53:24,434 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.27_S02715_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.27_S02715_I0141_D_3
# 2025-09-02 13:53:24,509 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.27_S02715_I0141_D_4 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.27_S02715_I0141_D_4
# 2025-09-02 13:53:24,577 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.28_S02716_I0141_D_1 -> /home/phd2/Scrivania/CorsoData/blastocisti/blasto/D2020.12.28_S02716_I0141_D_1
# 2025-09-02 13:53:24,641 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.28_S02716_I0141_D_2 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.28_S02716_I0141_D_2
# 2025-09-02 13:53:24,710 - INFO - Copied directory: /home/phd2/Scrivania/CorsoData/ScopeData_time_conversion/2020/D2020.12.28_S02716_I0141_D_3 -> /home/phd2/Scrivania/CorsoData/blastocisti/no_blasto/D2020.12.28_S02716_I0141_D_3
# Risultati organizzazione:
#   Moved count (attempts counted): 6002
#   Not moved examples (first 20):
# []

# %%
len(stats.get('not_moved'))
# Out:
# 0

# %%
target_scan_dir = DEST_DIR if DEST_DIR.exists() else SRC_DIR
log_file = (DEST_DIR / "corrupted_images_log.txt") if DEST_DIR.exists() else (Path('.') / "corrupted_images_log.txt")
print("Scanning directory:", target_scan_dir)
summary = check_for_corrupted_images(target_scan_dir, log_file_path=(log_file if SAVE_LOGS else None))
print("\n--- Summary ---")
print(f"Total images scanned: {summary['total_images']}")
print(f"Total corrupted images: {summary['corrupted_images']}")
print(f"Corrupted folders count: {summary['corrupted_folders_count']}")
print("Some per-folder counts (sample):")
import itertools
for k,v in itertools.islice(summary['per_folder'].items(), 10):
    print(k, "->", v)
if SAVE_LOGS:
    print("Log saved to:", log_file)
# Out:
# Scanning directory: /home/phd2/Scrivania/CorsoData/blastocisti
#
# --- Summary ---
# Total images scanned: 3779067
# Total corrupted images: 0
# Corrupted folders count: 0
# Some per-folder counts (sample):
# blasto -> {'total': 1586912, 'corrupted': 0}
# no_blasto -> {'total': 2192155, 'corrupted': 0}
# Log saved to: /home/phd2/Scrivania/CorsoData/blastocisti/corrupted_images_log.txt

# %%
if not FIX_IMAGES:
    print("FIX_IMAGES is False. Set FIX_IMAGES=True to run fixes (slow).")
else:
    target_fix_dir = DEST_DIR if DEST_DIR.exists() else SRC_DIR
    print("Attempting to fix images under:", target_fix_dir)
    res = fix_images_in_directory(target_fix_dir, image_extensions=('.jpg',), max_files=MAX_FIX_FILES)
    print("Fix results:", res)
    if SAVE_LOGS and DEST_DIR.exists():
        with open(DEST_DIR / 'fix_images_log.txt', 'w') as f:
            f.write(str(res))
        print("Fix log saved to:", DEST_DIR / 'fix_images_log.txt')
# Out:
# Attempting to fix images under: /home/phd2/Scrivania/CorsoData/blastocisti
# Fix results: {'attempted': 3779067, 'fixed': 3779067, 'errors': []}
# Fix log saved to: /home/phd2/Scrivania/CorsoData/blastocisti/fix_images_log.txt

# %%
from IPython.display import display
summary_items = {
    'moved_count': stats.get('moved_count', None),
    'not_moved_count': len(stats.get('not_moved', [])),
    'corrupted_total': summary.get('corrupted_images', None),
    'corrupted_folders': summary.get('corrupted_folders_count', None)
}
summary_df = pd.DataFrame([summary_items])
display(summary_df.T.rename(columns={0:'value'}))
if SAVE_LOGS and DEST_DIR.exists():
    summary_path = DEST_DIR / 'preprocessing_summary.csv'
    summary_df.to_csv(summary_path, index=False)
    print("Summary saved to:", summary_path)
# Out:
#                    value
# moved_count         6002
# not_moved_count        0
# corrupted_total        0
# corrupted_folders      0
# Summary saved to: /home/phd2/Scrivania/CorsoData/blastocisti/preprocessing_summary.csv

# %%
print("Full pipeline cell (only executes changes if DRY_RUN=False).")
print("Current DRY_RUN:", DRY_RUN)
print("To run the full pipeline with file moves set DRY_RUN=False and re-run this cell.")
# Out:
# Full pipeline cell (only executes changes if DRY_RUN=False).
# Current DRY_RUN: False
# To run the full pipeline with file moves set DRY_RUN=False and re-run this cell.
